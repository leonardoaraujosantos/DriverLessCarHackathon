# %% [markdown]
# ## Playing with OpenCV
#
# References:
# * http://docs.opencv.org/3.0-beta/doc/py_tutorials/py_gui/py_image_display/py_image_display.html
#
# ### Installig OpenCV on Anaconda (No issues with imshow)
# ```bash
# conda install -c https://conda.anaconda.org/menpo opencv3
# ```

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import sys
# %matplotlib inline

# %%
img = cv2.imread('cat.jpg')
img_gray = cv2.cvtColor( img, cv2.COLOR_RGB2GRAY )
# Need to convert from BGR to RGB to be used with matplotlib
imgRGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
# You can do but it will block the notebook
#cv2.imshow('image gray',img_gray)
#cv2.waitKey(0)
#cv2.destroyAllWindows()

# %%
plt.imshow(imgRGB)
plt.show()
